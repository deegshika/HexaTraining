# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder\
.appName("RDD Exercises")\
.getOrCreate()

# %%
activities=[
"LOGIN",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_START",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"VIDEO_PLAY",
"QUIZ_START",
"QUIZ_COMPLETE",
"LOGIN",
"VIDEO_PLAY",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"VIDEO_PLAY",
"QUIZ_START",
"LOGIN",
"COURSE_VIEW",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_COMPLETE",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_START",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_COMPLETE",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"LOGIN",
"QUIZ_START",
"COURSE_VIEW",
"VIDEO_PLAY",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY"
]

rdd=spark.sparkContext.parallelize(activities)

# %%
#1
rdd.collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY']

# %%
#2
rdd.count()
# Out:
# 50

# %%
#3
rdd.first()
# Out:
# 'LOGIN'

# %%
#4
rdd.take(10)
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
#5
rdd.collect()[-1]
# Out:
# 'VIDEO_PLAY'

# %%
#6
rdd.distinct().collect()
# Out:
# ['COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START']

# %%
#7
rdd.distinct().count()
# Out:
# 6

# %%
#8
rdd.sortBy(lambda x:x).collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'QUIZ_COMPLETE',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY']

# %%
#9
rdd.map(lambda x:x.upper()).collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY']

# %%
#10
rdd.map(lambda x:(x,len(x))).collect()
# Out:
# [('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_START', 10),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_COMPLETE', 13),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('QUIZ_START', 10),
# ...

# %%
#11
rdd.filter(lambda x:x=="LOGIN").collect()
# Out:
# ['LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN']

# %%
#12
rdd.filter(lambda x:x=="VIDEO_PLAY").collect()
# Out:
# ['VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY']

# %%
#13
rdd.filter(lambda x:x=="QUIZ_START").collect()
# Out:
# ['QUIZ_START', 'QUIZ_START', 'QUIZ_START', 'QUIZ_START', 'QUIZ_START']

# %%
#14
rdd.filter(lambda x:"QUIZ" in x).collect()
# Out:
# ['QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START']

# %%
#15
rdd.filter(lambda x:x.endswith("VIEW")).collect()
# Out:
# ['COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW']

# %%
#16
rdd.filter(lambda x:x!="LOGIN").collect()
# Out:
# ['COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
#17
rdd.filter(lambda x:x!="VIDEO_PLAY").collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN']

# %%
#18
rdd.filter(lambda x:len(x)>8).collect()
# Out:
# ['COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
#19
rdd.filter(lambda x:len(x)<10).collect()
# Out:
# ['LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN']

# %%
#20
rdd.filter(lambda x:x.startswith("C")).collect()
# Out:
# ['COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW']

# %%
#21
rdd.map(lambda x:x.lower()).collect()
# Out:
# ['login',
#  'course_view',
#  'login',
#  'video_play',
#  'quiz_start',
#  'video_play',
#  'login',
#  'course_view',
#  'assignment_submit',
#  'video_play',
#  'quiz_start',
#  'quiz_complete',
#  'login',
#  'video_play',
#  'course_view',
#  'login',
#  'video_play',
#  'video_play',
#  'quiz_start',
#  'login',
#  'course_view',
#  'course_view',
#  'assignment_submit',
#  'login',
#  'video_play',
#  'quiz_complete',
#  'login',
#  'course_view',
#  'video_play',
#  'video_play',
#  'login',
#  'course_view',
#  'quiz_start',
#  'assignment_submit',
#  'login',
#  'video_play',
#  'login',
#  'course_view',
#  'quiz_complete',
#  'video_play',
#  'login',
#  'course_view',
#  'video_play',
#  'login',
#  'quiz_start',
#  'course_view',
#  'video_play',
#  'assignment_submit',
#  'login',
#  'video_play']

# %%
#22
rdd.map(lambda x:"EVENT_"+x).collect()
# Out:
# ['EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_COURSE_VIEW',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_COURSE_VIEW',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_QUIZ_START',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
# ...

# %%
#23
rdd.map(lambda x:x+"_2025").collect()
# Out:
# ['LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'QUIZ_COMPLETE_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'COURSE_VIEW_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'COURSE_VIEW_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_COMPLETE_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'VIDEO_PLAY_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'QUIZ_START_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'QUIZ_COMPLETE_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'QUIZ_START_2025',
#  'COURSE_VIEW_2025',
# ...

# %%
#24
rdd.map(lambda x:len(x)).collect()
# Out:
# [5,
#  11,
#  5,
#  10,
#  10,
#  10,
#  5,
#  11,
#  17,
#  10,
#  10,
#  13,
#  5,
#  10,
#  11,
#  5,
#  10,
#  10,
#  10,
#  5,
#  11,
#  11,
#  17,
#  5,
#  10,
#  13,
#  5,
#  11,
#  10,
#  10,
#  5,
#  11,
#  10,
#  17,
#  5,
#  10,
#  5,
#  11,
#  13,
#  10,
#  5,
#  11,
#  10,
#  5,
#  10,
#  11,
#  10,
#  17,
#  5,
#  10]

# %%
#25
rdd.map(lambda x:(x,len(x))).collect()
# Out:
# [('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_START', 10),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_COMPLETE', 13),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('QUIZ_START', 10),
# ...

# %%
#26
rdd.map(lambda x:(x,1)).collect()
# Out:
# [('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('COURSE_VIEW', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('COURSE_VIEW', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('VIDEO_PLAY', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('QUIZ_START', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('QUIZ_START', 1),
#  ('COURSE_VIEW', 1),
# ...

# %%
#27
rdd.map(
lambda x:"USER_LOGIN"
if x=="LOGIN"
else x
).collect()
# Out:
# ['USER_LOGIN',
#  'COURSE_VIEW',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY']

# %%
#28
rdd.map(
lambda x:"WATCH_VIDEO"
if x=="VIDEO_PLAY"
else x
).collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'COURSE_VIEW',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO']

# %%
#29
rdd.map(lambda x:x[::-1]).collect()
# Out:
# ['NIGOL',
#  'WEIV_ESRUOC',
#  'NIGOL',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'TIMBUS_TNEMNGISSA',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'ETELPMOC_ZIUQ',
#  'NIGOL',
#  'YALP_OEDIV',
#  'WEIV_ESRUOC',
#  'NIGOL',
#  'YALP_OEDIV',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'WEIV_ESRUOC',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV',
#  'ETELPMOC_ZIUQ',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'TRATS_ZIUQ',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'ETELPMOC_ZIUQ',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'NIGOL',
#  'TRATS_ZIUQ',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV']

# %%
#30
rdd.map(lambda x:x[0]).collect()
# Out:
# ['L',
#  'C',
#  'L',
#  'V',
#  'Q',
#  'V',
#  'L',
#  'C',
#  'A',
#  'V',
#  'Q',
#  'Q',
#  'L',
#  'V',
#  'C',
#  'L',
#  'V',
#  'V',
#  'Q',
#  'L',
#  'C',
#  'C',
#  'A',
#  'L',
#  'V',
#  'Q',
#  'L',
#  'C',
#  'V',
#  'V',
#  'L',
#  'C',
#  'Q',
#  'A',
#  'L',
#  'V',
#  'L',
#  'C',
#  'Q',
#  'V',
#  'L',
#  'C',
#  'V',
#  'L',
#  'Q',
#  'C',
#  'V',
#  'A',
#  'L',
#  'V']

# %%
#31
rdd.distinct().collect()
# Out:
# ['COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START']

# %%
#32
rdd.distinct().count()
# Out:
# 6

# %%
#33
rdd.distinct().sortBy(
lambda x:x
).collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'VIDEO_PLAY']

# %%
#34
rdd.distinct().filter(
lambda x:"QUIZ" in x
).collect()
# Out:
# ['QUIZ_COMPLETE', 'QUIZ_START']

# %%
#35
rdd.distinct().filter(
lambda x:"COURSE" in x
).collect()
# Out:
# ['COURSE_VIEW']

# %%
#36
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'LOGIN': 14,
#              'COURSE_VIEW': 10,
#              'VIDEO_PLAY': 14,
#              'QUIZ_START': 5,
#              'ASSIGNMENT_SUBMIT': 4,
#              'QUIZ_COMPLETE': 3})

# %%
#37
activity_count=rdd.countByValue()

max(activity_count,
key=activity_count.get)
# Out:
# 'LOGIN'

# %%
#38
activity_count=rdd.countByValue()

min(activity_count,
key=activity_count.get)
# Out:
# 'QUIZ_COMPLETE'

# %%
#39
activity_count=rdd.countByValue()

sorted(
activity_count.items(),
key=lambda x:x[1]
)
# Out:
# [('QUIZ_COMPLETE', 3),
#  ('ASSIGNMENT_SUBMIT', 4),
#  ('QUIZ_START', 5),
#  ('COURSE_VIEW', 10),
#  ('LOGIN', 14),
#  ('VIDEO_PLAY', 14)]

# %%
#40
activity_count=rdd.countByValue()

{k:v for k,v in activity_count.items()
if v>5}
# Out:
# {'LOGIN': 14, 'COURSE_VIEW': 10, 'VIDEO_PLAY': 14}

# %%
#41
extra_activities=[
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

rdd2=spark.sparkContext.parallelize(
extra_activities
)

rdd.union(rdd2).collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'CERTIFICATE_DOWNLOAD',
#  'VIDEO_PLAY',
#  'PROFILE_UPDATE',
#  'QUIZ_COMPLETE']

# %%
#42
extra_activities=[
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

rdd2=spark.sparkContext.parallelize(
extra_activities
)

rdd.union(rdd2).count()
# Out:
# 55

# %%
#43
extra_activities=[
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

rdd2=spark.sparkContext.parallelize(
extra_activities
)

rdd.union(rdd2).distinct().collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'CERTIFICATE_DOWNLOAD',
#  'PROFILE_UPDATE',
#  'COURSE_VIEW',
#  'LOGIN']

# %%
#44
extra_activities=[
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

rdd2=spark.sparkContext.parallelize(
extra_activities
)

rdd.union(rdd2).countByValue()
# Out:
# defaultdict(int,
#             {'LOGIN': 15,
#              'COURSE_VIEW': 10,
#              'VIDEO_PLAY': 15,
#              'QUIZ_START': 5,
#              'ASSIGNMENT_SUBMIT': 4,
#              'QUIZ_COMPLETE': 4,
#              'CERTIFICATE_DOWNLOAD': 1,
#              'PROFILE_UPDATE': 1})

# %%
#45
extra_activities=[
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

rdd2=spark.sparkContext.parallelize(
extra_activities
)

rdd2.subtract(rdd).collect()
# Out:
# ['CERTIFICATE_DOWNLOAD', 'PROFILE_UPDATE']

# %%
#46
rdd3=spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

rdd.intersection(rdd3).collect()
# Out:
# ['QUIZ_COMPLETE', 'COURSE_VIEW', 'LOGIN']

# %%
#47
rdd3=spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

rdd.intersection(rdd3).count()
# Out:
# 3

# %%
#48
rdd3=spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

rdd.intersection(rdd3)\
.sortBy(lambda x:x)\
.collect()
# Out:
# ['COURSE_VIEW', 'LOGIN', 'QUIZ_COMPLETE']

# %%
#49
rdd3=spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

rdd.intersection(rdd3)\
.filter(lambda x:"QUIZ" in x)\
.collect()
# Out:
# ['QUIZ_COMPLETE']

# %%
#50
rdd3=spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

rdd.intersection(rdd3)\
.filter(lambda x:"LOGIN" in x)\
.collect()
# Out:
# ['LOGIN']

# %%
#51
numbers=[
120,
250,
300,
450,
600,
750,
900,
1050,
1200,
1350,
1500,
1650,
1800,
1950,
2100
]

sales_rdd=spark.sparkContext.parallelize(
numbers
)

sales_rdd.reduce(
lambda x,y:x+y
)
# Out:
# 15970

# %%
#52
sales_rdd.reduce(
lambda x,y:x
if x>y
else y
)
# Out:
# 2100

# %%
#53
sales_rdd.reduce(
lambda x,y:x
if x<y
else y
)
# Out:
# 120

# %%
#54
sales_rdd.reduce(
lambda x,y:x+y
)/sales_rdd.count()
# Out:
# 1064.6666666666667

# %%
#55
sales_rdd.filter(
lambda x:x>1000
).count()
# Out:
# 8

# %%
#56
sales_rdd.map(
lambda x:x*2
).collect()
# Out:
# [240,
#  500,
#  600,
#  900,
#  1200,
#  1500,
#  1800,
#  2100,
#  2400,
#  2700,
#  3000,
#  3300,
#  3600,
#  3900,
#  4200]

# %%
#57
sales_rdd.map(
lambda x:x+100
).collect()
# Out:
# [220,
#  350,
#  400,
#  550,
#  700,
#  850,
#  1000,
#  1150,
#  1300,
#  1450,
#  1600,
#  1750,
#  1900,
#  2050,
#  2200]

# %%
#58
sales_rdd.sortBy(
lambda x:x
).collect()
# Out:
# [120,
#  250,
#  300,
#  450,
#  600,
#  750,
#  900,
#  1050,
#  1200,
#  1350,
#  1500,
#  1650,
#  1800,
#  1950,
#  2100]

# %%
#59
sales_rdd.sortBy(
lambda x:x,
ascending=False
).collect()
# Out:
# [2100,
#  1950,
#  1800,
#  1650,
#  1500,
#  1350,
#  1200,
#  1050,
#  900,
#  750,
#  600,
#  450,
#  300,
#  250,
#  120]

# %%
#60
sales_rdd.takeOrdered(
5,
key=lambda x:-x
)
# Out:
# [2100, 1950, 1800, 1650, 1500]

# %%
#61
courses=[
"Python SQL Spark",
"Azure Databricks Spark",
"Python Pandas NumPy",
"SQL Spark DeltaLake",
"Azure Python SQL"
]

course_rdd=spark.sparkContext.parallelize(
courses
)

course_rdd.flatMap(
lambda x:x.split()
).collect()
# Out:
# ['Python',
#  'SQL',
#  'Spark',
#  'Azure',
#  'Databricks',
#  'Spark',
#  'Python',
#  'Pandas',
#  'NumPy',
#  'SQL',
#  'Spark',
#  'DeltaLake',
#  'Azure',
#  'Python',
#  'SQL']

# %%
#62
course_rdd.flatMap(
lambda x:x.split()
).count()
# Out:
# 15

# %%
#63
course_rdd.flatMap(
lambda x:x.split()
).distinct().collect()
# Out:
# ['Python',
#  'SQL',
#  'Databricks',
#  'Pandas',
#  'DeltaLake',
#  'Spark',
#  'Azure',
#  'NumPy']

# %%
#64
course_rdd.flatMap(
lambda x:x.split()
).sortBy(
lambda x:x
).collect()
# Out:
# ['Azure',
#  'Azure',
#  'Databricks',
#  'DeltaLake',
#  'NumPy',
#  'Pandas',
#  'Python',
#  'Python',
#  'Python',
#  'SQL',
#  'SQL',
#  'SQL',
#  'Spark',
#  'Spark',
#  'Spark']

# %%
#65
course_rdd.flatMap(
lambda x:x.split()
).countByValue()
# Out:
# defaultdict(int,
#             {'Python': 3,
#              'SQL': 3,
#              'Spark': 3,
#              'Azure': 2,
#              'Databricks': 1,
#              'Pandas': 1,
#              'NumPy': 1,
#              'DeltaLake': 1})

# %%
#66
course_rdd.flatMap(
lambda x:x.split()
).filter(
lambda x:"Python" in x
).collect()
# Out:
# ['Python', 'Python', 'Python']

# %%
#67
course_rdd.flatMap(
lambda x:x.split()
).filter(
lambda x:"Spark" in x
).collect()
# Out:
# ['Spark', 'Spark', 'Spark']

# %%
#68
course_rdd.flatMap(
lambda x:x.split()
).map(
lambda x:x.upper()
).collect()
# Out:
# ['PYTHON',
#  'SQL',
#  'SPARK',
#  'AZURE',
#  'DATABRICKS',
#  'SPARK',
#  'PYTHON',
#  'PANDAS',
#  'NUMPY',
#  'SQL',
#  'SPARK',
#  'DELTALAKE',
#  'AZURE',
#  'PYTHON',
#  'SQL']

# %%
#69
words=course_rdd.flatMap(
lambda x:x.split()
).collect()

max(words,key=len)
# Out:
# 'Databricks'

# %%
#70
words=course_rdd.flatMap(
lambda x:x.split()
).collect()

min(words,key=len)
# Out:
# 'SQL'

# %%
#71
activity_count=rdd.countByValue()

max(
activity_count,
key=activity_count.get
)
# Out:
# 'LOGIN'

# %%
#72
activity_count=rdd.countByValue()

min(
activity_count,
key=activity_count.get
)
# Out:
# 'QUIZ_COMPLETE'

# %%
#73
login_count=rdd.filter(
lambda x:x=="LOGIN"
).count()

total_count=rdd.count()

(login_count/total_count)*100
# Out:
# 28.000000000000004

# %%
#74
video_count=rdd.filter(
lambda x:x=="VIDEO_PLAY"
).count()

total_count=rdd.count()

(video_count/total_count)*100
# Out:
# 28.000000000000004

# %%
#75
activity_report=rdd.countByValue()

print(activity_report)
# Out:
# defaultdict(<class 'int'>, {'LOGIN': 14, 'COURSE_VIEW': 10, 'VIDEO_PLAY': 14, 'QUIZ_START': 5, 'ASSIGNMENT_SUBMIT': 4, 'QUIZ_COMPLETE': 3})

# %%
#76
unique_report=rdd.distinct().collect()

print(unique_report)
# Out:
# ['COURSE_VIEW', 'ASSIGNMENT_SUBMIT', 'QUIZ_COMPLETE', 'LOGIN', 'VIDEO_PLAY', 'QUIZ_START']

# %%
#77
frequency_report=rdd.countByValue()

print(frequency_report)
# Out:
# defaultdict(<class 'int'>, {'LOGIN': 14, 'COURSE_VIEW': 10, 'VIDEO_PLAY': 14, 'QUIZ_START': 5, 'ASSIGNMENT_SUBMIT': 4, 'QUIZ_COMPLETE': 3})

# %%
#78
rdd.distinct().saveAsTextFile(
"distinct_activities"
)

# %%
#79
frequency_rdd=spark.sparkContext.parallelize(
list(rdd.countByValue().items())
)

frequency_rdd.saveAsTextFile(
"activity_frequency"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5228/58305677.py in <cell line: 0>()
#       1 #79
# ----> 2 frequency_rdd=spark.sparkContext.parallelize(
#       3 list(rdd.countByValue().items())
#       4 )
#       5
#
# NameError: name 'spark' is not defined

# %%
# !rm -rf activity_frequency

# %% [markdown]
# Now that the existing output directory has been removed, you can re-run the cell above to save the `frequency_rdd`.

# %%
#80
print("Total Activities:",rdd.count())

print("Unique Activities:",
rdd.distinct().count())

print("Most Common Activity:",
max(
rdd.countByValue(),
key=rdd.countByValue().get
))

print("Least Common Activity:",
min(
rdd.countByValue(),
key=rdd.countByValue().get
))
# Out:
# Total Activities: 50
# Unique Activities: 6
# Most Common Activity: LOGIN
# Least Common Activity: QUIZ_COMPLETE
