# %%
bookings_data = [
(1,"Rahul",8500),
(2,"Priya",22000),
(3,"Amit",9000),
(4,"Sneha",15000),
(5,"Farhan",7500)
]

columns = [
    "booking_id",
    "customer_name",
    "ticket_price"
]

df_bookings = spark.createDataFrame(
    bookings_data,
    columns
)

display(df_bookings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>booking_id</th><th>customer_name</th><th>ticket_price</th></tr></thead><tbody><tr><td>1</td><td>Rahul</td><td>8500</td></tr><tr><td>2</td><td>Priya</td><td>22000</td></tr><tr><td>3</td><td>Amit</td><td>9000</td></tr><tr><td>4</td><td>Sneha</td><td>15000</td></tr><tr><td>5</td><td>Farhan</td><td>7500</td></tr></tbody></table></div>

# %%
df_bookings.write \
    .mode("overwrite") \
    .saveAsTable("managed_booking_table")

# %%
df_bookings.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/ey_databricksss_7405605087274576/default/output_data/external_booking_table")

# %%
spark.sql("""

CREATE OR REPLACE TABLE external_booking_table
AS SELECT * FROM delta.`/Volumes/ey_databricksss_7405605087274576/default/output_data/external_booking_table`

""")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8684119913483857>, line 1
# ----> 1 spark.sql("""
#       2
#       3 CREATE OR REPLACE TABLE external_booking_table
#       4 SHALLOW CLONE delta.`/Volumes/ey_databricksss_7405605087274576/default/output_data/external_booking_table`
#       5
#       6 """)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     898         _views.append(SubqueryAlias(df._plan, name))
#     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     902 if "sql_command_result" in properties:
#     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# ...

# %%
df_bookings.createOrReplaceTempView(
    "temp_bookings"
)
